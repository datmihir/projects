# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot
# %matplotlib inline

# %%
df = pd.read_excel('Rice_Cammeo_Osmancik.xlsx')
df
# Out:
#        Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0     15231  525.578979         229.749878          85.093788      0.928882
# 1     14656  494.311005         206.020065          91.730972      0.895405
# 2     14634  501.122009         214.106781          87.768288      0.912118
# 3     13176  458.342987         193.337387          87.448395      0.891861
# 4     14688  507.166992         211.743378          89.312454      0.906691
# ...     ...         ...                ...                ...           ...
# 3805  11441  415.858002         170.486771          85.756592      0.864280
# 3806  11625  421.390015         167.714798          89.462570      0.845850
# 3807  12437  442.498993         183.572922          86.801979      0.881144
# 3808   9882  392.296997         161.193985          78.210480      0.874406
# 3809  11434  404.709991         161.079269          90.868195      0.825692
#
#       Convex_Area    Extent     Class
# 0           15617  0.572896    Cammeo
# 1           15072  0.615436    Cammeo
# 2           14954  0.693259    Cammeo
# 3           13368  0.640669    Cammeo
# 4           15262  0.646024    Cammeo
# ...           ...       ...       ...
# 3805        11628  0.681012  Osmancik
# 3806        11904  0.694279  Osmancik
# 3807        12645  0.626739  Osmancik
# 3808        10097  0.659064  Osmancik
# 3809        11591  0.802949  Osmancik
#
# [3810 rows x 8 columns]

# %%
df.describe()
# Out:
#                Area     Perimeter  Major_Axis_Length  Minor_Axis_Length  \
# count  3.810000e+03  3.810000e+03       3.810000e+03       3.810000e+03
# mean   5.967813e-17 -1.790344e-16      -1.193563e-16      -5.669422e-16
# std    1.000000e+00  1.000000e+00       1.000000e+00       1.000000e+00
# min   -2.953604e+00 -2.672668e+00      -2.493699e+00      -4.674031e+00
# 25%   -7.488177e-01 -7.892340e-01      -8.265593e-01      -6.251605e-01
# 50%   -1.421335e-01 -1.513238e-01      -1.699936e-01       2.109949e-02
# 75%    7.401849e-01  8.271624e-01       8.467241e-01       6.684203e-01
# max    3.605050e+00  2.646475e+00       2.878973e+00       3.704952e+00
#
#        Eccentricity   Convex_Area        Extent        Class
# count  3.810000e+03  3.810000e+03  3.810000e+03  3810.000000
# mean   6.266204e-16 -5.371032e-16 -4.848848e-16     0.572178
# std    1.000000e+00  1.000000e+00  1.000000e+00     0.494828
# min   -5.266589e+00 -2.942926e+00 -2.130034e+00     0.000000
# 25%   -6.950351e-01 -7.463521e-01 -8.165818e-01     0.000000
# 50%    1.046992e-01 -1.384360e-01 -2.145634e-01     1.000000
# 75%    7.550077e-01  7.493101e-01  8.367238e-01     1.000000
# max    2.936761e+00  3.458976e+00  2.577922e+00     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3810 entries, 0 to 3809
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Area               3810 non-null   int64
#  1   Perimeter          3810 non-null   float64
#  2   Major_Axis_Length  3810 non-null   float64
#  3   Minor_Axis_Length  3810 non-null   float64
#  4   Eccentricity       3810 non-null   float64
#  5   Convex_Area        3810 non-null   int64
#  6   Extent             3810 non-null   float64
#  7   Class              3810 non-null   int64
# dtypes: float64(5), int64(3)
# memory usage: 238.2 KB

# %%
df['Class'].replace({'Cammeo':0, 'Osmancik':1}, inplace = True)

# %%
for column in df_std.columns:
  if column != 'Class':
    df[column] = (df[column] - df[column].mean()) / df[column].std()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.drop('Class', axis=1), df['Class'], test_size=0.3, random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score

classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    SVC(gamma=2, C=1),
    GaussianNB(),
    DecisionTreeClassifier(),
    RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
    AdaBoostClassifier()
]

for classifier in classifiers:
    classifier.fit(X_train, y_train)
    y_pred = classifier.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"{classifier.__class__.__name__}: {accuracy}")
# Out:
# KNeighborsClassifier: 0.9125109361329834
# SVC: 0.9343832020997376
# SVC: 0.9282589676290464
# GaussianNB: 0.926509186351706
# DecisionTreeClassifier: 0.8923884514435696
# RandomForestClassifier: 0.9308836395450568
# AdaBoostClassifier: 0.9282589676290464

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_neighbors': [3, 5, 7],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'leaf_size': [30, 40, 50],
}

grid_search = GridSearchCV(KNeighborsClassifier(), param_grid, cv=5)

grid_search.fit(X_train, y_train)

print(grid_search.best_params_)

best_model = grid_search.best_estimator_

accuracy = accuracy_score(y_test, best_model.predict(X_test))
print(f"Accuracy of the best model: {accuracy}")
# Out:
# {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 7}
# Accuracy of the best model: 0.9273840769903762
